# %%
import pypsa

# %%
n = pypsa.Network("./data/NG/elec_s_5_ec_lcopt_Co2L-4H.nc");
n_h2= pypsa.Network("./data/WITH_H2/elec_s_5_ec_lcopt_Co2L-4H.nc");

n_n= pypsa.Network("./data/elec_s_5_ec_lcopt_Co2L-4H.nc");
# Out:
# INFO:pypsa.io:Imported network elec_s_5_ec_lcopt_Co2L-4H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# INFO:pypsa.io:Imported network elec_s_5_ec_lcopt_Co2L-4H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# INFO:pypsa.io:Imported network elec_s_5_ec_lcopt_Co2L-4H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x20e373aa560>,
# ...
#  <matplotlib.collections.LineCollection at 0x20e37440580>)
# e:\installs\envs\pypsa-earth\lib\site-packages\cartopy\mpl\style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
n_h2.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x20e3f6ff010>,
# ...
#  <matplotlib.collections.LineCollection at 0x20e3f70ce20>)
# e:\installs\envs\pypsa-earth\lib\site-packages\cartopy\mpl\style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
print(n.statistics())
# Out:
#                                 Capacity Factor  Capital Expenditure  \
#             carrier
# Generator   Combined-Cycle Gas              NaN                  0.0
#             Oil                             NaN                  0.0
#             Onshore Wind                    NaN                  0.0
#             Open-Cycle Gas                  NaN                  0.0
#             Solar                           NaN                  0.0
# Line        -                               NaN                  0.0
# Link        H2 electrolysis                 NaN                  0.0
#             H2 fuel cell                    NaN                  0.0
#             battery charger                 NaN                  0.0
#             battery discharger              NaN                  0.0
# Load        -                               NaN                  NaN
# StorageUnit Reservoir & Dam                 NaN                  0.0
# ...

# %%
print(n_h2.statistics())
# Out:
#                                 Capacity Factor  Capital Expenditure  \
#             carrier
# Generator   Combined-Cycle Gas              NaN                  0.0
#             Oil                             NaN                  0.0
#             Onshore Wind                    NaN                  0.0
#             Open-Cycle Gas                  NaN                  0.0
#             Solar                           NaN                  0.0
# Line        -                               NaN                  0.0
# Link        H2 electrolysis                 NaN                  0.0
#             H2 fuel cell                    NaN                  0.0
#             H2 pipeline                     NaN                  0.0
#             battery charger                 NaN                  0.0
#             battery discharger              NaN                  0.0
# Load        -                               NaN                  NaN
# ...

# %%
n.statistics()
# Out:
#                                 Capacity Factor  Capital Expenditure  \
#             carrier
# Generator   Combined-Cycle Gas              NaN                  0.0
#             Oil                             NaN                  0.0
#             Onshore Wind                    NaN                  0.0
#             Open-Cycle Gas                  NaN                  0.0
#             Solar                           NaN                  0.0
# Line        -                               NaN                  0.0
# Link        H2 electrolysis                 NaN                  0.0
#             H2 fuel cell                    NaN                  0.0
#             battery charger                 NaN                  0.0
#             battery discharger              NaN                  0.0
# Load        -                               NaN                  NaN
# StorageUnit Reservoir & Dam                 NaN                  0.0
# ...
